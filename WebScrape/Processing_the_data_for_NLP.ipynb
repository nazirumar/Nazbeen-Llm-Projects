# %%
from bs4 import BeautifulSoup
import os

def extract_text_from_html(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
        if content.strip().startswith('<?xml'):
            # Use XML parser
            soup = BeautifulSoup(content, 'xml')
        else:
            # Use HTML parser
            soup = BeautifulSoup(content, 'html.parser')
        return soup.get_text()

# %%
def extract_text_from_directory(directory_path):
    texts = []
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.endswith('.html') or file.endswith('.xml'):
                file_path = os.path.join(root, file)
                text = extract_text_from_html(file_path)
                texts.append(text)
    return texts

# %%
import re

# %%
text_ =[]

# %%
directory_path = 'techcrunch.com'
all_texts = extract_text_from_directory(directory_path)
for text in all_texts:
    text_.append(re.sub('\n', '', text))

# %%
text= ''.join(text_)


new_string = ''.join(text.split('\n'))
print(new_string)
# Out:
# TechCrunch | Startup and Technology News  LoginSearchStartupsVentureAppleSecurityAIAppsEventsStartup BattlefieldMoreFintechCloud ComputingLayoffsHardwareGoogleMicrosoftTransportationEVsMetaInstagramAmazonTikTokNewslettersPodcastsPartner ContentCrunchboard JobsContact UsSearch		Hardware	After nine years, Google’s Nest Learning Thermostat gets an AI makeoverBrian Heater 		Security	Cyberattack knocks Mobile Guardian MDM offline and wipes thousands of student devicesZack Whittaker 		Social	X files antitrust suit against advertising groups over ‘systematic illegal boycott’Brian Heater 		Hardware	Chromecast is dead. Meet Google TV StreamerBrian Heater 		Apps	Breaking up Google would offer a chance to remodel the webNatasha LomasThe Latest		Transportation	Rivian lost $1.46B in Q2 as it drives toward a VW-linked futureSean O'Kane	59 mins agoRivian’s financial losses have crept up as it pushed out the last of its first-generation R1 trucks and SUVs in favor of newer, more cost-efficient versi
# ...

# %%
with open('techcrunch.txt', 'w') as f:
          f.write(new_string)
