# %% [markdown]
# ## Exploring Text Data
#
# Working with text is generally more challenging than working with numerical data. Hence, any kind of technique that helps in generating an intuition of the existing dataset is welcome. One of the simplest approach to understand any text document or to compare multiple documents can be to compute a frequency table of individual words present in the document/documents and use it to conduct further experiements like: finding top words per document, finding top common words among documents etc.
#
# In our case, we have taken the challenge of Analyzing Sentiments from Twitter data, so we will focus on how to generate word frequencies and use it to create **Word Clouds** in Python that will help us get a better overall understanding of the dataset.
#
# **Note:-** We are using the same dataset from `tweets.csv` that we used earlier. You can get it [here.](https://studio.trainings.analyticsvidhya.com/assets/courseware/v1/aa0ae6514e0be95f11be85b84d4fd6d2/asset-v1:AnalyticsVidhya+NLP101+2018_T1+type@asset+block/tweets.csv)
#
# ### Table of Contents
# 1. About the Dataset
# 2. Generating Word Frequency
# 3. EDA using Word Clouds
# 4. Why to Preprocess text data?
# 5. Challenge

# %% [markdown]
# ### 1. About the Dataset
#
# The dataset that we are going to use is the same dataset of tweets from Twitter that will be used in module 8 for **Social Media Information Extraction**. You can download it from [here.](https://studio.trainings.analyticsvidhya.com/assets/courseware/v1/aa0ae6514e0be95f11be85b84d4fd6d2/asset-v1:AnalyticsVidhya+NLP101+2018_T1+type@asset+block/tweets.csv)
# Let's load the dataset using pandas and have a quick look at some sample tweets.

# %%
#Load the dataset
import pandas as pd 
dataset = pd.read_csv('tweets.csv', encoding = 'ISO-8859-1')

dataset.head()
# Out:
#    Unnamed: 0  X                                               text  \
# 0           1  1  RT @rssurjewala: Critical question: Was PayTM ...
# 1           2  2  RT @Hemant_80: Did you vote on #Demonetization...
# 2           3  3  RT @roshankar: Former FinSec, RBI Dy Governor,...
# 3           4  4  RT @ANI_news: Gurugram (Haryana): Post office ...
# 4           5  5  RT @satishacharya: Reddy Wedding! @mail_today ...
#
#    favorited  favoriteCount replyToSN              created  truncated  \
# 0      False              0       NaN  2016-11-23 18:40:30      False
# 1      False              0       NaN  2016-11-23 18:40:29      False
# 2      False              0       NaN  2016-11-23 18:40:03      False
# 3      False              0       NaN  2016-11-23 18:39:59      False
# 4      False              0       NaN  2016-11-23 18:39:39      False
#
#    replyToSID            id  replyToUID  \
# 0         NaN  8.014957e+17         NaN
# 1         NaN  8.014957e+17         NaN
# 2         NaN  8.014955e+17         NaN
# 3         NaN  8.014955e+17         NaN
# 4         NaN  8.014954e+17         NaN
#
#                                         statusSource       screenName  \
# 0  <a href="http://twitter.com/download/android" ...  HASHTAGFARZIWAL
# 1  <a href="http://twitter.com/download/android" ...   PRAMODKAUSHIK9
# 2  <a href="http://twitter.com/download/android" ...  rahulja13034944
# 3  <a href="http://twitter.com/download/android" ...        deeptiyvd
# 4  <a href="http://cpimharyana.com" rel="nofollow...        CPIMBadli
#
#    retweetCount  isRetweet  retweeted
# 0           331       True      False
# 1            66       True      False
# 2            12       True      False
# 3           338       True      False
# 4           120       True      False

# %% [markdown]
# As can be seen above, **text** column is of interest to us as it contains the tweet. At this point, you don't have to worry about other columns as that will be handled in future modules. Let's go ahead and inspect some of the tweets.
#
# ### 2. Generating Word Frequency
#
# Let's first generate a frequency table of all the words present in all the tweets combined.

# %%
def gen_freq(text):
    #Will store the list of words
    word_list = []

    #Loop over all the tweets and extract words into word_list
    for tw_words in text.split():
        word_list.extend(tw_words)

    #Create word frequencies using word_list
    word_freq = pd.Series(word_list).value_counts()

    #Print top 20 words
    word_freq[:20]
    
    return word_freq

gen_freq(dataset.text.str)
# Out:
# RT                         11053
# to                          7650
# is                          5152
# in                          4491
# the                         4331
#                            ...
# #News                          1
# notes|                         1
# https://t.co/ECl4oIzdHA        1
# https://t.co/9MjFtLtCtR        1
# https://t.co/hwgqjbqgvG        1
# Name: count, Length: 19601, dtype: int64

# %% [markdown]
# ### 3. EDA using Word Clouds
#
# Now that you have succesfully created a frequency table, you can use that to create multiple **visualizations** in the form of word clouds. Sometimes, the quickest way to understand the context of the text data is using a word cloud of top 100-200 words. Let's see how to create that in Python.
#
# **Note:-** You'll use the `WordCloud` library of Python. You can install it by -
#
# `pip install wordcloud`

# %%
word_freq = gen_freq(dataset.text.str)

# %%
#Import libraries
import matplotlib.pyplot as plt
from wordcloud import WordCloud

#Generate word cloud
wc = WordCloud(width=400, height=330, max_words=100, background_color='white').generate_from_frequencies(word_freq)

plt.figure(figsize=(12, 8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# **Few things to Note:-**
#
# 1. There is noise in the form of "RT" and "&amp" which can be removed from the word frequency.
# 2. Stop words like "the", "in", "to", "of" etc. are obviously ranking among the top frequency words but these are just constructs of the English language and are not specific to the people's tweets.
# 3. Words like "demonetization" have occured multiple times. The reason for this is that the current text is not **Normalized** so words like "demonetization", "Demonetization" etc. are all considered as different words.
#
# The above are some of the problems that we need to address in order to make better visualization. Let's solve some of the problems!
#
# #### Text Cleaning
#
# You have already learnt how to utilize Regex to do text cleaning, that is precisely what we are doing here.

# %%
import re
import string

def clean_text(text):
    #Remove RT
    text = re.sub(r'RT', '', text)
    
    #Fix &
    text = re.sub(r'&amp;', '&', text)
    
    #Remove punctuations
    text = re.sub(r'[?!.;:,#@-]', '', text)

    #Convert to lowercase to maintain consistency
    text = text.lower()
    
    return text

# %% [markdown]
# The above will solve problems related to RT, &amp and also the problem of counting same word twice due to case difference. Yet we can do better, let's remove the common stop words.
#
# #### Stop words Removal
# WordCloud provides its own stopwords list. You can have a look at it by-

# %%
#Import list of stopwards
from wordcloud import STOPWORDS

print(STOPWORDS)
# Out:
# {"he'd", 'further', 'about', "that's", 'while', 'could', "we've", 'himself', 'ourselves', 'but', 'so', 'him', "you've", 'have', 'below', 'any', 'then', 'of', "how's", 'why', "she'll", "she's", 'until', 'in', 'all', 'again', "shouldn't", 'ours', 'am', "let's", 'themselves', 'else', 'few', 'them', 'for', "he's", 'to', "here's", 'those', 'otherwise', 'we', 'he', "didn't", 'some', "aren't", 'between', 'they', 'through', 'theirs', 'that', 'doing', 'by', 'it', 'does', "couldn't", 'what', 'her', 'k', "when's", 'not', 'as', "i've", "wasn't", 'nor', 'shall', 'a', 'into', 'over', 'own', "mustn't", 'our', 'www', 'other', 'myself', 'because', 'above', 'down', 'was', 'http', "we'd", 'is', 'had', 'the', 'only', 'should', "why's", "i'd", "you're", 'each', 'ought', "we'll", 'would', 'than', 'and', 'therefore', 'here', 'with', "who's", 'such', 'be', "you'll", 'get', 'during', 'hence', "isn't", "it's", "they're", 'who', 'been', 'most', "won't", 'having', "there's", "you'd", 'at', 'yourself', 'since', "shan't", "they'll", 'how', 'its', 'where', 'when', 'however', 'my', 'these', 'same', 'cannot', 'an', "i'm", 'this', 'herself', 'she', 'i', 'more', 'no', 'r', 'after', 'both', 'me', "i'll", 'or', 'out', 'on', 'too', "where's", 'yourselves', 'once', 'just', "hadn't", "we're", 'yours', 'their', "haven't", 'were', 'also', 'under', 'are', "what's", 'your', 'very', "he'll", "they'd", 'from', 'do', "they've", "weren't", "wouldn't", "she'd", 'did', 'com', 'his', 'hers', 'whom', "doesn't", 'up', 'has', 'there', 'which', 'like', "don't", "hasn't", 'off', 'before', 'can', 'you', 'if', 'being', 'against', 'itself', "can't", 'ever'}

# %% [markdown]
# Now that you know what all has to be changed to improve our word cloud, let's make some wordclouds. We'll call the previous functions of `clean_text()` and `gen_freq()` to perform cleaning and frequency computation operation respectively and drop the words present in `STOPWORDS` from the `word_freq` dictionary.

# %%
text = dataset.text.apply(lambda x: clean_text(x))
word_freq = gen_freq(text.str)*100
word_freq = word_freq.drop(labels=STOPWORDS, errors='ignore')

#Generate word cloud
wc = WordCloud(width=450, height=330, max_words=200, background_color='white').generate_from_frequencies(word_freq)

plt.figure(figsize=(10, 14))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import re
import string

def clean_text(text):
    #Remove RT
    text = re.sub(r'RT', '', text)
    
    #Fix &
    text = re.sub(r'&amp;', '&', text)
    
    #Remove punctuations
    text = re.sub(r'[?!.;:,#@-]', '', text)

    #Convert to lowercase to maintain consistency
    text = text.lower()
    text = text.translate(str.maketrans('', '', string.punctuation))

    return text

# %%
text = dataset.text.apply(lambda x: clean_text(x))
word_freq = gen_freq(text.str)*100
word_freq = word_freq.drop(labels=STOPWORDS, errors='ignore')

#Generate word cloud
wc = WordCloud(width=450, height=330, max_words=200, background_color='white').generate_from_frequencies(word_freq)

plt.figure(figsize=(10, 14))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# Now that you have succesfully created a wordcloud, you can get some insight into the areas of interest of the general twitter users:
#
#  - It is evident that people are talking about govt. policies like **demonetization**, **J&K**.
#  - There are some personalitites that are mentioned numerous times like **evanspiegel**, **PM Narendra Modi**, **Dr Kumar Vishwas** etc.
#  - There are also talks about **oscars**, **youtube** and **terrorists**
#  - There are many sub-topics that revolve around demonetization like **atms**, **bank**, **cash**, **paytm** etc. Which tells that many people are concerned about it.
#
# ### 4. Why to Preprocess text data?
#
# As you may have already seen that without performing preprocessing operations like cleaning, removing stopwords and changing case in the dataset the representation always comes out wrong. In this case, it was that the wordcloud was full of noise but in other cases it might be your Machine Learning model that is going to suffer.
#
# Also something to note is even now some words are misreperesented for example: **modi**, **narendra** and **narendramodi** all refer to the same person. This can eaisly be solved by **Normalizing** our text which is a technique that you'll learn in future models.

# %% [markdown]
# ### 5. Challenge
#
# As you would have noticed, even the current word cloud has some form of noise especially from strange symbols like `<U...>`. It's your task to go ahead and figure out how to deal with the, given the fact that they are present in word cloud implies that noise is widely present in the data.

# %%
word_freq
# Out:
# demonetization        1394300
# india                  276600
# modi                   275900
# pm                     272900
# narendra               156600
#                        ...
# akhara                    100
# httpstco62oskppcgd        100
# httpstco4zal0uofe2        100
# httpstco4jxnntvgqf        100
# httpstcohwgqjbqgvg        100
# Name: count, Length: 14140, dtype: int64

# %%
texts = text.to_list()

# %%
from nltk.corpus import stopwords


tokens = [word for tweet in texts for word in tweet.split()]
stop_words = set(stopwords.words('english'))
tokens = [word for word in tokens if word not in stop_words]
tokens
# Out:
# ['rssurjewala',
#  'critical',
#  'question',
#  'paytm',
#  'informed',
#  'demonetization',
#  'edict',
#  'pm',
#  'clearly',
#  'fishy',
#  'requires',
#  'full',
#  'disclosure',
#  'hemant80',
#  'vote',
#  'demonetization',
#  'modi',
#  'survey',
#  'app',
#  'roshankar',
#  'former',
#  'finsec',
#  'rbi',
#  'dy',
#  'governor',
#  'cbdt',
#  'chair',
#  'harvard',
#  'professor',
#  'lambaste',
#  'demonetization',
#  'aam',
#  'aadmi',
#  'listen',
#  'th',
#  'aninews',
#  'gurugram',
#  'haryana',
#  'post',
#  'office',
#  'employees',
#  'provide',
#  'cash',
#  'exchange',
#  'patients',
#  'hospitals',
#  'demonetization',
#  'httpstcougmxup9',
#  'satishacharya',
#  'reddy',
#  'wedding',
#  'mailtoday',
#  'cartoon',
#  'demonetization',
#  'reddywedding',
#  'httpstcou7glnrq31f',
#  'derekscissors1',
#  'india\x92s',
#  'demonetization',
#  'blackmoney',
#  'symptom',
#  'disease',
#  'httpstcohsl6ihj0qe',
#  'via',
#  'ambazaarmag',
#  'gauravcsawant',
#  'rs',
#  '40',
#  'lakh',
#  'looted',
#  'bank',
#  'kishtwar',
#  'jk',
#  'third',
#  'incident',
#  'since',
#  'demonetization',
#  'thats',
#  'terrorists',
#  'joydeep911',
#  'calling',
#  'nationalists',
#  'join',
#  'walk',
#  'corruptionfreeindia',
#  'spread',
#  'benefits',
#  'demonetization',
#  'among',
#  'mas',
#  'sumitbhati2002',
#  'many',
#  'opposition',
#  'leaders',
#  'narendramodi',
#  'demonetization',
#  'respect',
#  'decisionbut',
#  'support',
#  'oppositio',
#  'national',
#  'reform',
#  'destroyed',
#  'even',
#  'essence',
#  'sagan',
#  'instances',
#  'urge',
#  'giving',
#  'demonetization',
#  'second',
#  'though',
#  'httpstcoeyysireiuq',
#  'many',
#  'opposition',
#  'leaders',
#  'narendramodi',
#  'demonetization',
#  'respect',
#  'decisionbut',
#  'support',
#  'opposition',
#  'bcoz',
#  'party',
#  'joydas',
#  'question',
#  'narendra',
#  'modi',
#  'app',
#  'pm',
#  'taking',
#  'feedback',
#  'people',
#  'support',
#  'demonetization',
#  'strategy',
#  'httpstcopygk8rmg7r',
#  'jaggesh2',
#  'bharat',
#  'band',
#  '28edu00a0u00bdedu00b8u0082those',
#  'protesting',
#  'demonetization',
#  'different',
#  'party',
#  'leaders',
#  'atheistkrishna',
#  'effect',
#  'demonetization',
#  'httpstcoa8of7zh2f5',
#  'sona2905',
#  'explained',
#  'demonetization',
#  'tried',
#  'put',
#  'words',
#  'laced',
#  'heavy',
#  'technical',
#  'dipankarcpiml',
#  'modi',
#  'app',
#  'demonetization',
#  'proves',
#  'govt',
#  'totally',
#  'indifferent',
#  'mounting',
#  'misery',
#  'hards',
#  'roshankar',
#  'former',
#  'finsec',
#  'rbi',
#  'dy',
#  'governor',
#  'cbdt',
#  'chair',
#  'harvard',
#  'professor',
#  'lambaste',
#  'demonetization',
#  'aam',
#  'aadmi',
#  'listen',
#  'th',
#  'atheistkrishna',
#  'gandhi',
#  'ji',
#  'heard',
#  'standing',
#  'demonetization',
#  'httpstco9nhek63tpg',
#  'pgurus1',
#  'demonetization',
#  'cooperative',
#  'banking',
#  'sector',
#  'kerala',
#  'good',
#  'tax',
#  'kerala',
#  'black',
#  'money',
#  'hq',
#  'httpstco',
#  'roshankar',
#  'former',
#  'finsec',
#  'rbi',
#  'dy',
#  'governor',
#  'cbdt',
#  'chair',
#  'harvard',
#  'professor',
#  'lambaste',
#  'demonetization',
#  'aam',
#  'aadmi',
#  'listen',
#  'th',
#  'hemant80',
#  'vote',
#  'demonetization',
#  'modi',
#  'survey',
#  'app',
#  'roshankar',
#  'former',
#  'finsec',
#  'rbi',
#  'dy',
#  'governor',
#  'cbdt',
#  'chair',
#  'harvard',
#  'professor',
#  'lambaste',
#  'demonetization',
#  'aam',
#  'aadmi',
#  'listen',
#  'th',
#  'atheistkrishna',
#  'gandhi',
#  'ji',
#  'heard',
#  'standing',
#  'demonetization',
#  'httpstco9nhek63tpg',
#  'mahikainfra',
#  'narendramodi',
#  'swamy39',
#  'success',
#  'demonetization',
#  'depend',
#  'swiftly',
#  'govt',
#  'replenish',
#  'currency',
#  'pls',
#  'avoid',
#  'ba',
#  'hemant80',
#  'vote',
#  'demonetization',
#  'modi',
#  'survey',
#  'app',
#  'roshankar',
#  'former',
#  'finsec',
#  'rbi',
#  'dy',
#  'governor',
#  'cbdt',
#  'chair',
#  'harvard',
#  'professor',
#  'lambaste',
#  'demonetization',
#  'aam',
#  'aadmi',
#  'listen',
#  'th',
#  'kapilkausik',
#  'doltiwal',
#  'mean',
#  'jaichandkejriwal',
#  'hurt',
#  'demonetization',
#  'rendered',
#  'useless',
#  'edu00a0u00bdedu00b1u0089',
#  'acquired',
#  'funds',
#  'wo',
#  'roshankar',
#  'former',
#  'finsec',
#  'rbi',
#  'dy',
#  'governor',
#  'cbdt',
#  'chair',
#  'harvard',
#  'professor',
#  'lambaste',
#  'demonetization',
#  'aam',
#  'aadmi',
#  'listen',
#  'th',
#  'kapilkausik',
#  'doltiwal',
#  'mean',
#  'jaichandkejriwal',
#  'hurt',
#  'demonetization',
#  'rendered',
#  'useless',
#  'edu00a0u00bdedu00b1u0089',
#  'acquired',
#  'funds',
#  'wo',
#  'aapvind',
#  'demonetization',
#  'disaster',
#  'naampk',
#  'hemant80',
#  'vote',
#  'demonetization',
#  'modi',
#  'survey',
#  'app',
#  'gadgets360',
#  'demonetization',
#  'searches',
#  'narendramodis',
#  'app',
#  'trending',
#  'app',
#  'stores',
#  'httpstcozetkrqqclx',
#  'avenu',
#  'teacher',
#  'anybody',
#  'absent',
#  'today',
#  'response',
#  'teacher',
#  'says',
#  '100',
#  'attendance',
#  'demonetization',
#  'app',
#  'survey',
#  'donmu',
#  'drgpradhan',
#  '8',
#  'tweet',
#  'minimathur',
#  'bibi',
#  'explains',
#  'prob',
#  'demonetization',
#  'first',
#  'part',
#  'says',
#  'cant',
#  'mayankjain100',
#  'demonetization',
#  'communal',
#  'black',
#  'money',
#  'secular',
#  'lol',
#  'demonetization',
#  'effect',
#  'httpstcoaa5lfy9alg',
#  'kapilkausik',
#  'doltiwal',
#  'mean',
#  'jaichandkejriwal',
#  'hurt',
#  'demonetization',
#  'rendered',
#  'useless',
#  'edu00a0u00bdedu00b1u0089',
#  'acquired',
#  'funds',
#  'wo',
#  'roshankar',
#  'harvards',
#  'larry',
#  'summers',
#  'calls',
#  'demonetization',
#  'poor',
#  'policy',
#  'disproportionate',
#  'negative',
#  'impact',
#  'httpstcotpyjgxfby8',
#  'atheistkrishna',
#  'gandhi',
#  'ji',
#  'heard',
#  'standing',
#  'demonetization',
#  'httpstco9nhek63tpg',
#  'arunjaitley',
#  'narendramodi',
#  'lrnd',
#  'frm',
#  'frndbanks',
#  'r',
#  'asking',
#  'employees',
#  'comeback',
#  '2sales',
#  'bau',
#  'operations',
#  'demonetization',
#  'kanimozhi',
#  'ts',
#  'exactly',
#  'pappu',
#  'opposition',
#  'done',
#  'opposing',
#  'demonetization',
#  'none',
#  'stop',
#  'modi',
#  'bandwagon',
#  'ti',
#  'roshankar',
#  'harvards',
#  'larry',
#  'summers',
#  'calls',
#  'demonetization',
#  'poor',
#  'policy',
#  'disproportionate',
#  'negative',
#  'impact',
#  'poortrade',
#  'httpst',
#  'drgpradhan',
#  '8',
#  'tweet',
#  'minimathur',
#  'bibi',
#  'explains',
#  'prob',
#  'demonetization',
#  'first',
#  'part',
#  'says',
#  'cant',
#  'dineshgrao',
#  '125',
#  'k',
#  'followers',
#  'yet',
#  'getting',
#  'enough',
#  'likes',
#  'tweets',
#  'demonetization',
#  'need',
#  'introspect',
#  'demonetization',
#  'effect',
#  'visa',
#  'master',
#  'card',
#  'amex',
#  'accepted',
#  'httpstcoozdwcpkjai',
#  'drgpradhan',
#  '8',
#  'tweet',
#  'minimathur',
#  'bibi',
#  'explains',
#  'prob',
#  'demonetization',
#  'first',
#  'part',
#  'says',
#  'cant',
#  'harshkkapoor',
#  'demonetization',
#  'survey',
#  'results',
#  '24',
#  'hours',
#  '5lacs',
#  'opinions',
#  'amazing',
#  'response',
#  'commitment',
#  'fight',
#  'blackmoney',
#  'na',
#  'roshankar',
#  'former',
#  'finsec',
#  'rbi',
#  'dy',
#  'governor',
#  'cbdt',
#  'chair',
#  'harvard',
#  'professor',
#  'lambaste',
#  'demonetization',
#  'aam',
#  'aadmi',
#  'listen',
#  'th',
#  'rohanmlw',
#  'demonetization',
#  'eye',
#  'opener',
#  'video',
#  'bt',
#  'doubt',
#  'jurnos',
#  'dont',
#  'want2',
#  'hear',
#  'narendramodi',
#  'sardesairajdeep',
#  'ravishndtv',
#  'punitspeaks',
#  'survey',
#  'result',
#  'far',
#  'pmoindia',
#  'demonetization',
#  '5',
#  'lakh',
#  'response',
#  '24',
#  'hrs',
#  '90',
#  'supports',
#  'note',
#  'ban',
#  'meradeshbadalraha',
#  'nmleo1',
#  'modisarkar',
#  'achedin',
#  'campaign',
#  'demonetization',
#  'goebbelsian',
#  'masterstroke',
#  'turns',
#  'blind',
#  'eye',
#  'groundzero',
#  'shocks',
#  'punitspeaks',
#  'survey',
#  'result',
#  'far',
#  'pmoindia',
#  'demonetization',
#  '5',
#  'lakh',
#  'response',
#  '24',
#  'hrs',
#  '90',
#  'supports',
#  'note',
#  'ban',
#  'meradeshbadalraha',
#  'drgpradhan',
#  '8',
#  'tweet',
#  'minimathur',
#  'bibi',
#  'explains',
#  'prob',
#  'demonetization',
#  'first',
#  'part',
#  'says',
#  'cant',
#  'demonetization',
#  'communal',
#  'black',
#  'money',
#  'secular',
#  'kapilkausik',
#  'doltiwal',
#  'mean',
#  'jaichandkejriwal',
#  'hurt',
#  'demonetization',
#  'rendered',
#  'useless',
#  'edu00a0u00bdedu00b1u0089',
#  'acquired',
#  'funds',
#  'wo',
#  'nmleo1',
#  'minhazmerchant',
#  'demonetization',
#  'hardly',
#  'affects',
#  'tax',
#  'dodgers',
#  'netas',
#  'excel',
#  'cashlesscorruption',
#  'multiplied',
#  'bad',
#  'weal',
#  'atheistkrishna',
#  'gandhi',
#  'ji',
#  'heard',
#  'standing',
#  'demonetization',
#  'httpstco9nhek63tpg',
#  'section',
#  '144',
#  'issued',
#  'district',
#  'magistrate',
#  'indore',
#  'prohibiting',
#  'socialmedia',
#  'posts',
#  'demonetization',
#  'citizen',
#  'httpstco5tn7anbtsi',
#  'pgurus1',
#  'cpim',
#  'opposes',
#  'coop',
#  'banks',
#  'west',
#  'bengal',
#  'supports',
#  'kerala',
#  'pawar',
#  'uturned',
#  'demonetization',
#  'httpstcothzav7r',
#  'roshankar',
#  'harvards',
#  'larry',
#  'summers',
#  'calls',
#  'demonetization',
#  'poor',
#  'policy',
#  'disproportionate',
#  'negative',
#  'impact',
#  'httpstcovcwwjxu0wb',
#  'zeenewssports',
#  'demonetization',
#  'harbhajansingh',
#  'gives',
#  'hilarious',
#  'shagun',
#  'suggestion',
#  'struggling',
#  'wedding',
#  'season',
#  'httpst',
#  'gauravcsawant',
#  'rs',
#  '40',
#  'lakh',
#  'looted',
#  'bank',
#  'kishtwar',
#  'jk',
#  'third',
#  'incident',
#  'since',
#  'demonetization',
#  'thats',
#  'terrorists',
#  'pgurus1',
#  'demonetization',
#  'time',
#  'come',
#  'put',
#  'mudra',
#  'action',
#  'writes',
#  'prof',
#  'r',
#  'vaidyanathan',
#  'httpstcop6hkkdva3b',
#  'upma23',
#  'uns',
#  'pgurus1',
#  'demonetization',
#  'move',
#  'modi',
#  'supporting',
#  'opposing',
#  'complete',
#  'coverage',
#  'parties',
#  'httpst',
#  'joydas',
#  'question',
#  'narendra',
#  'modi',
#  'app',
#  'pm',
#  'taking',
#  'feedback',
#  'people',
#  'support',
#  'demonetization',
#  'strategy',
#  'httpstcopygk8rmg7r',
#  'modibharosa',
#  'huge',
#  'support',
#  'pm',
#  'narendramodi',
#  '\x92s',
#  'demonetization',
#  'move',
#  'across',
#  'nation',
#  '8086',
#  'people',
#  'back',
#  'demonetization',
#  'cvoter',
#  'su',
#  'effects',
#  'sluggish',
#  'economy',
#  'negative',
#  'iip',
#  'demonetization',
#  'great',
#  'leader',
#  'even',
#  'bother',
#  'except',
#  'continued',
#  'dra',
#  'httpstcoduvbmtei1y',
#  'kanimozhi',
#  'ts',
#  'exactly',
#  'pappu',
#  'opposition',
#  'done',
#  'opposing',
#  'demonetization',
#  'none',
#  'stop',
#  'modi',
#  'bandwagon',
#  'ti',
#  'roshankar',
#  'harvards',
#  'larry',
#  'summers',
#  'calls',
#  'demonetization',
#  'poor',
#  'policy',
#  'disproportionate',
#  'negative',
#  'impact',
#  'httpstco5j6jzxby81',
#  'drgpradhan',
#  '8',
#  'tweet',
#  'minimathur',
#  'bibi',
#  'explains',
#  'prob',
#  'demonetization',
#  'first',
#  'part',
#  'says',
#  'cant',
#  'bhaiyyajispeaks',
#  'sardesairajdeep',
#  'struggling',
#  'one',
#  'answer',
#  'demonetization',
#  'taken',
#  'congress',
#  'leader',
#  'lik',
#  'demonetization',
#  'indian',
#  'economy',
#  'interview',
#  'doordarshan',
#  'sri',
#  'sgurumurthy',
#  'httpstcoldebcadaer',
#  'gadgets360',
#  'demonetization',
#  'searches',
#  'narendramodis',
#  'app',
#  'trending',
#  'app',
#  'stores',
#  'httpstcozetkrqqclx',
#  'roshankar',
#  'former',
#  'finsec',
#  'rbi',
#  'dy',
#  'governor',
#  'cbdt',
#  'chair',
#  'harvard',
#  'professor',
#  'lambaste',
#  'demonetization',
#  'aam',
#  'aadmi',
#  'listen',
#  'th',
#  'punitspeaks',
#  'survey',
#  'result',
#  'far',
#  'pmoindia',
#  'demonetization',
#  '5',
#  'lakh',
#  'response',
#  '24',
#  'hrs',
#  '90',
#  'supports',
#  'note',
#  'ban',
#  'meradeshbadalraha',
#  'nilimdutta',
#  'much',
#  'contemplation',
#  'come',
#  'conclusion',
#  'nothing',
#  'explains',
#  'modis',
#  'demonetization',
#  'better',
#  'monumental',
#  'currencycrisis',
#  'demonetization',
#  'indicates',
#  'loss',
#  'freedom',
#  'besides',
#  'lawsconstitutioncourtcops',
#  '2',
#  'govern',
#  'people',
#  'govt',
#  'using',
#  'hemant80',
#  'vote',
#  'demonetization',
#  'modi',
#  'survey',
#  'app',
#  'ppl',
#  'india',
#  'extending',
#  'overwhelming',
#  'supprt',
#  'narendramodi',
#  'jis',
#  'crusade',
#  'agnst',
#  'black',
#  'moneysurvey',
#  'timesofindia',
#  'httpstcoaxqd8fowpk',
#  'roshankar',
#  'harvards',
#  'larry',
#  'summers',
#  'calls',
#  'demonetization',
#  'poor',
#  'policy',
#  'disproportionate',
#  'negative',
#  'impact',
#  'poortrade',
#  'httpst',
#  'gauravcsawant',
#  'rs',
#  '40',
#  'lakh',
#  'looted',
#  'bank',
#  'kishtwar',
#  'jk',
#  'third',
#  'incident',
#  'since',
#  'demonetization',
#  'thats',
#  'terrorists',
#  'harshkkapoor',
#  'demonetization',
#  'survey',
#  'results',
#  '24',
#  'hours',
#  '5lacs',
#  'opinions',
#  'amazing',
#  'response',
#  'commitment',
#  'fight',
#  'blackmoney',
#  'na',
#  'people',
#  'rural',
#  'areas',
#  'coming',
#  'delhi',
#  'withdraw',
#  'cash',
#  'given',
#  'govt',
#  'logistics',
#  'ravishndtv',
#  'demonetization',
#  'rssurjewala',
#  'critical',
#  'question',
#  'paytm',
#  'informed',
#  'demonetization',
#  'edict',
#  'pm',
#  'clearly',
#  'fishy',
#  'requires',
#  'full',
#  'disclosure',
#  'zeenewssports',
#  'demonetization',
#  'harbhajansingh',
#  'gives',
#  'hilarious',
#  'shagun',
#  'suggestion',
#  'struggling',
#  'wedding',
#  'season',
#  'httpst',
#  'roshankar',
#  'harvards',
#  'larry',
#  'summers',
#  'calls',
#  'demonetization',
#  'poor',
#  'policy',
#  'disproportionate',
#  'negative',
#  'impact',
#  'poortrade',
#  'httpst',
#  'roshankar',
#  'harvards',
#  'larry',
#  'summers',
#  'calls',
#  'demonetization',
#  'poor',
#  'policy',
#  'disproportionate',
#  'negative',
#  'impact',
#  ...]

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
tokens = [lemmatizer.lemmatize(word) for word in tokens]

# %%
preprocessed_text = ' '.join(tokens)
preprocessed_text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 preprocessed_text = ' '.join(tokens)
#       2 preprocessed_text
#
# NameError: name 'tokens' is not defined

# %%
from keras.preprocessing.text import Tokenizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from keras.preprocessing.text import Tokenizer
#
# ModuleNotFoundError: No module named 'keras'

# %%
tokenizer = Toke
